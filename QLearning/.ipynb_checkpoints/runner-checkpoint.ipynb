# %%
from train import *

# %%
mainCycle()
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
# started learning
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 0/5 [00:01<?, ?it/s]
#
#
#
#
#
#
#
#
#
#  20%|██        | 1/5 [00:01<00:00,  8.46it/s]
#
#
#
#
#
#
#
#
#
#  40%|████      | 2/5 [00:03<00:02,  1.40it/s]
#
#
#
#
#
#
#
#
#
#  60%|██████    | 3/5 [00:04<00:01,  1.04it/s]
#
#
#
#
#
#
#
#
#
#  80%|████████  | 4/5 [00:05<00:01,  1.01s/it]
#
#
#
#
#
#
#
#
#
# 100%|██████████| 5/5 [00:07<00:00,  1.10s/it]
# totalDisqountedReward = 0.000003
# pureRewardPerGame  = 1.000000
# GameMemorySize = 10000
# ...
